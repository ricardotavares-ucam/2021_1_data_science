# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
imovel =  pd.read_csv("df_clean.csv" , sep=';')
imovel
# Out:
#       sales_price   area  bedrooms  bathrooms  garage     tax  zip_code  \
# 0        610000.0   50.0         1          1       0   390.0  22250210
# 1       1020000.0   74.0         2          2       1     0.0  22260040
# 2       1735000.0   93.0         3          1       1  1371.0  22280110
# 3        800000.0   88.0         3          1       0   440.0  22260140
# 4        229000.0   23.0         0          1       0   540.0  22250040
# 5       1350057.0  114.0         3          3       2  1400.0  22260100
# 6       1250000.0   79.0         3          1       1   873.0  22281033
# 7       2100000.0  308.0         3          2       1   800.0  22251040
# 8        350000.0   21.0         0          1       0   350.0  22250040
# 9       1938000.0  132.0         3          4       2     0.0  22280020
# 10       395000.0   25.0         1          1       0   450.0  22250040
# 11      1150000.0   60.0         2          1       1  1280.0  22290010
# ...

# %%
imovel.describe("sales_price")
# Out:
#           bedrooms    bathrooms       garage     zip_code
# count  2664.000000  2664.000000  2664.000000  2.664000e+03
# mean      2.459835     1.914414     1.014264  2.227067e+07
# std       0.898888     0.951803     0.758345  1.493724e+04
# min       0.000000     1.000000     0.000000  2.223009e+07
# 25%       2.000000     1.000000     0.000000  2.226000e+07
# 50%       2.000000     2.000000     1.000000  2.227111e+07
# 75%       3.000000     2.000000     1.000000  2.228103e+07
# max       5.000000     5.000000     4.000000  2.229097e+07

# %%
imovel
imovel_teste['sales_price'] = imovel_teste['sales_price'].astype(float)

# %%
imovel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 15 columns):
# sales_price         2664 non-null float64
# area                2664 non-null float64
# bedrooms            2664 non-null int64
# bathrooms           2664 non-null int64
# garage              2664 non-null int64
# tax                 2664 non-null float64
# zip_code            2664 non-null int64
# latitude            2664 non-null float64
# longitude           2664 non-null float64
# subway              2664 non-null float64
# botafogo_beach      2664 non-null float64
# rio_sul             2664 non-null float64
# leme_beach          2664 non-null float64
# copacabana_beach    2664 non-null float64
# santa_marta         2664 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 312.3 KB

# %%
Q1 = imovel["sales_price"].quantile(0.25)
Q1
# Out:
# 735000.0

# %%
Q2 = imovel['sales_price'].quantile(0.50)
Q2
# Out:
# 1050000.0

# %%
Q3 = imovel['sales_price'].quantile(0.75)
Q3
# Out:
# 1600000.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 865000.0

# %%
LI= Q1 - ( 1.5 * IQR)
LI
# Out:
# -562500.0

# %%
LS = Q3 + ( 1.5 * IQR)
LS
# Out:
# 2897500.0

# %%
imovel.boxplot('sales_price',figsize = (16,20))
