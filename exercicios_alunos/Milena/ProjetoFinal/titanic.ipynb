# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test =  pd.read_csv("test.csv" , sep=',')
train =  pd.read_csv("train.csv" , sep=',')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#train['PassengerId'].groupby(['Pclass'])
passageiros_classe = train.groupby("Pclass")["PassengerId"].count()
print(passageiros_classe)
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
passageiros_genero = train.groupby("Sex")["PassengerId"].count()
print(passageiros_genero)
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
passageiros_idade = train.groupby("Age")["PassengerId"].count()
print(passageiros_idade)
# Out:
# Age
# 0.42      1
# 0.67      1
# 0.75      2
# 0.83      2
# 0.92      1
# 1.00      7
# 2.00     10
# 3.00      6
# 4.00     10
# 5.00      4
# 6.00      3
# 7.00      3
# 8.00      4
# 9.00      8
# 10.00     2
# 11.00     4
# 12.00     1
# 13.00     2
# 14.00     6
# 14.50     1
# 15.00     5
# 16.00    17
# 17.00    13
# 18.00    26
# 19.00    25
# 20.00    15
# 20.50     1
# 21.00    24
# 22.00    27
# 23.00    15
#          ..
# 44.00     9
# 45.00    12
# 45.50     2
# 46.00     3
# 47.00     9
# 48.00     9
# 49.00     6
# 50.00    10
# 51.00     7
# 52.00     6
# 53.00     1
# 54.00     8
# 55.00     2
# 55.50     1
# 56.00     4
# 57.00     2
# 58.00     5
# 59.00     2
# 60.00     4
# 61.00     3
# 62.00     4
# 63.00     2
# 64.00     2
# 65.00     3
# 66.00     1
# 70.00     2
# 70.50     1
# 71.00     2
# 74.00     1
# 80.00     1
# Name: PassengerId, Length: 88, dtype: int64

# %%
sobreviventes = train['Survived'].value_counts()[1]
falecidos = train['Survived'].value_counts()[0]

print("Sobreviventes = ",sobreviventes)
print("Falecidos = ",falecidos)
# Out:
# Sobreviventes =  342
# Falecidos =  549

# %%
#train['Pclass','PassengerId'].groupby(['Pclass']).count()

# %%
train['Survived'].value_counts().plot.pie(colors=('tab:red', 'tab:blue'),  fontsize=15, startangle=180,autopct='%1.1f%%', labels=('Falecidos','Sobreviventes'), figsize=(5,5)).set_ylabel('')
# Out:
# Text(0, 0.5, '')
